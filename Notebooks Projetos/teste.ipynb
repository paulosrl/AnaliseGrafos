# %%
import pandas as pd
import networkx as nx

# Ler o arquivo CSV
df = pd.read_csv('nosarestas.csv')

# Criar um grafo vazio
G = nx.Graph()

# Adicionar arestas ao grafo
for _, row in df.iterrows():
    G.add_edge(row['origem'], row['destino'], weight=row['peso'])

# Agora G é um grafo com arestas e pesos

pos = nx.spring_layout(G)  # Definir a posição dos nós
nx.draw(G, pos, with_labels=True)  # Desenhar nós e arestas
edge_labels = nx.get_edge_attributes(G, 'weight')  # Obter os pesos das arestas
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)  # Adicionar rótulos às arestas


#nx.draw_networkx(G)
# Out:
# {(1, 2): Text(-0.09576813088249221, -0.2581878254810877, '2'),
#  (1, 3): Text(0.18922224608708132, 0.0719627932990755, '2'),
#  (1, 5): Text(0.4424915744846765, -0.17155649730717631, '3'),
#  (2, 3): Text(-0.10941735492303656, 0.010555166557213114, '1'),
#  (2, 4): Text(-0.6659272218340629, -0.49879639536151177, '2'),
#  (3, 5): Text(0.4288423504441322, 0.09718649473112453, '1'),
#  (3, 6): Text(0.22343564734938656, 0.6703528926686881, '2')}

# %%
import matplotlib.pyplot as plt

# Definir a posição dos nós
pos = nx.spring_layout(G)

# Obter os pesos das arestas
weights = nx.get_edge_attributes(G, 'weight')

# Normalizar os pesos para o intervalo [0, 1] para usar como espessura da linha
max_weight = max(weights.values())
normalized_weights = [w / max_weight for w in weights.values()]

# Desenhar nós e arestas
nx.draw(G, pos, with_labels=True, width=normalized_weights)

# Mostrar o gráfico
plt.show()
