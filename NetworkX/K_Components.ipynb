# %% [markdown]
# ##Import of Libraries

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## K-Components

# %%
G = nx.Graph()
G.add_edges_from([(1,2),(1, 3), (2, 3), (3, 4), (4, 5)])

nx.draw(G,with_labels=True)

# Compute the k-components of the graph

k_components = nx.k_components(G)

# Print the k-components
for k,components in k_components.items():
  print(f"{k}-components:")
  for component in components:
    print(component)
  print()
# Out:
# 2-components:
# {1, 2, 3}
#
# 1-components:
# {1, 2, 3, 4, 5}

# %%
G = nx.Graph()
G.add_edges_from([(1,2),(1, 3), (2, 3), (3, 4), (4, 5),(6,7),(6,8),(7,8)])

nx.draw(G,with_labels=True)

# Compute the k-components of the graph

k_components = nx.k_components(G)

# Print the k-components
for k,components in k_components.items():
  print(f"{k}-components:")
  for component in components:
    print(component)
  print()
# Out:
# 2-components:
# {1, 2, 3}
# {8, 6, 7}
#
# 1-components:
# {1, 2, 3, 4, 5}
# {8, 6, 7}
