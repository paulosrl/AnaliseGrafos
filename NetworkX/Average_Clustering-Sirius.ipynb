# %% [markdown]
# ##Import of Libraries

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Average Clustering

# %%
# criação do grafo
G = nx.Graph()

G.add_edges_from([(1, 2), (1, 3), (2, 3), (3, 4), (3, 5),  (4,5),(4,2),(1,4),(5,1),(5,2)])

nx.draw(G,with_labels=True)

# cálculo da média do coeficiente de clustering
# quando todos os nós estão ligados entre si, o valor será igual a 1
# quanto menor o coeficiente de clustering, menos conexões existirá entre os nós.

avg_clustering = nx.average_clustering(G)

print("Média do Coeficiente de clustering: ",avg_clustering)
# Out:
# Média do Coeficiente de clustering:  1.0

# %%
# criação do grafo
G = nx.Graph()

G.add_edges_from([(1, 2), (2, 3), (3, 4),(1,4),(4,2)])

nx.draw(G,with_labels=True)

# cálculo da média do coeficiente de clustering
# quando todos os nós estão ligados entre si, o valor será igual a 1
# quanto menor o coeficiente de clustering, menos conexões existirá entre os nós.

avg_clustering = nx.average_clustering(G)

print("Média do Coeficiente de clustering: ",avg_clustering)
# Out:
# Média do Coeficiente de clustering:  0.8333333333333333

# %%
# criação do grafo
G = nx.Graph()

G.add_edges_from([(1, 2), (2, 3), (3, 4),(1,4)])

nx.draw(G,with_labels=True)

# cálculo da média do coeficiente de clustering
# quando todos os nós estão ligados entre si, o valor será igual a 1
# quanto menor o coeficiente de clustering, menos conexões existirá entre os nós.

avg_clustering = nx.average_clustering(G)

print("Média do Coeficiente de clustering: ",avg_clustering)
# Out:
# Média do Coeficiente de clustering:  0.0

# %%
# criação do grafo
G = nx.Graph()

G.add_edges_from([(1, 2),(1, 3),(1,4)])
#G.add_edges_from([(1, 2), (1, 3), (2, 3),(3,4),(3,5)])
nx.draw(G,with_labels=True)

# cálculo da média do coeficiente de clustering
# quando todos os nós estão ligados entre si, o valor será igual a 1
# quanto menor o coeficiente de clustering, menos conexões existirá entre os nós.

avg_clustering = nx.average_clustering(G)

print("Média do Coeficiente de clustering: ",avg_clustering)
# Out:
# Média do Coeficiente de clustering:  0.0
