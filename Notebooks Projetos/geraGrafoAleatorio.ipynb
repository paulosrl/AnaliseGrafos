# %% [markdown]
# <a href="https://colab.research.google.com/github/paulosrl/AnaliseGrafos/blob/main/pivys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import numpy as np
import uuid
import pyvis
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import numpy as np
import copy

# %%
def get_new_test_graph(nodes=50, p=0.5, seed=1, m1=2, m2=1):
    # hard code parameters and use seed to replicate same network each time
    TG = nx.dual_barabasi_albert_graph(n=nodes, p=p, seed=seed, m1=m1, m2=m2)

    ### append node properties

    # 1. Compute Node Degree
    nx.set_node_attributes(TG, dict(TG.degree()), name='degree')
    # 2. Compute betweenness centrality
    nx.set_node_attributes(TG, nx.betweenness_centrality(TG), name='betweenness_centrality')

    for node, data in TG.nodes(data=True):
        # 3. Simulate node level features
        data['feature1'] = np.random.random()
        data['feature2'] = np.random.randint(0, high=100)
        data['feature3'] = 1 if np.random.random() > 0.5 else 0

        # 4. Simulate UIDs as node identifiers
        data['node_identifier'] = str(uuid.uuid4())

    ### append edge properties
    for u, v, data in TG.edges(data=True):

        # Simulate edge level features
        data['feature1'] = np.random.random()
        data['feature2'] = np.random.randint(0, high=100)

    return TG

# %%
G = get_new_test_graph(nodes=20)
nx.draw(G)

# %%
# propriedades dos nós
G.nodes(data=True)
# Out:
# NodeDataView({0: {'degree': 8, 'betweenness_centrality': 0.3138401559454191, 'feature1': 0.9099802444812046, 'feature2': 27, 'feature3': 0, 'node_identifier': '1ab69db3-eb95-4df6-8480-a349c8b081ed'}, 1: {'degree': 2, 'betweenness_centrality': 0.0, 'feature1': 0.9271485322538046, 'feature2': 19, 'feature3': 0, 'node_identifier': '1ba94599-9c24-4947-87dc-61e733ac4369'}, 2: {'degree': 2, 'betweenness_centrality': 0.014619883040935672, 'feature1': 0.3483639883058013, 'feature2': 45, 'feature3': 0, 'node_identifier': 'ea6d4b62-53ac-4e9b-b3f2-2951a4179890'}, 3: {'degree': 8, 'betweenness_centrality': 0.405458089668616, 'feature1': 0.9023918004977062, 'feature2': 60, 'feature3': 1, 'node_identifier': 'd3275af6-1e5f-460b-8c6c-bfa7dce2d49a'}, 4: {'degree': 3, 'betweenness_centrality': 0.11306042884990253, 'feature1': 0.9916298629818171, 'feature2': 90, 'feature3': 1, 'node_identifier': '32797da4-fb80-446f-b611-2da7f08ca7e8'}, 5: {'degree': 5, 'betweenness_centrality': 0.09649122807017543, 'feature1': 0.11734999964279713, 'feature2': 11, 'feature3': 1, 'node_identifier': 'bc170b58-f266-4ece-bfd7-63a01bf42c6f'}, 6: {'degree': 3, 'betweenness_centrality': 0.01461988304093567, 'feature1': 0.3637184008862484, 'feature2': 29, 'feature3': 0, 'node_identifier': '79c761e1-fc0a-4b44-9b2e-2caeb65c0ec5'}, 7: {'degree': 2, 'betweenness_centrality': 0.00682261208576998, 'feature1': 0.7232180160262451, 'feature2': 67, 'feature3': 1, 'node_identifier': '64bbc050-3573-44de-a96f-6d6450826790'}, 8: {'degree': 1, 'betweenness_centrality': 0.0, 'feature1': 0.3572916648997446, 'feature2': 21, 'feature3': 0, 'node_identifier': 'c5a0109d-8b1d-43f9-b175-48949bc8f5e0'}, 9: {'degree': 6, 'betweenness_centrality': 0.27680311890838205, 'feature1': 0.8740576342414941, 'feature2': 39, 'feature3': 0, 'node_identifier': '2de6edc8-28a9-48ba-bdda-7a30601e5a6c'}, 10: {'degree': 1, 'betweenness_centrality': 0.0, 'feature1': 0.03169580766601532, 'feature2': 19, 'feature3': 0, 'node_identifier': '66075d8c-1677-4018-bec1-224314b5f6de'}, 11: {'degree': 6, 'betweenness_centrality': 0.27680311890838205, 'feature1': 0.7227042253298754, 'feature2': 2, 'feature3': 1, 'node_identifier': '2d721070-f35f-4bc8-8eba-e95150f2b9e6'}, 12: {'degree': 1, 'betweenness_centrality': 0.0, 'feature1': 0.6706267038643937, 'feature2': 11, 'feature3': 0, 'node_identifier': 'aeff7e6b-da37-4d9f-8ba5-b1c942673df7'}, 13: {'degree': 1, 'betweenness_centrality': 0.0, 'feature1': 0.28209826853891773, 'feature2': 81, 'feature3': 1, 'node_identifier': 'a3ee3086-87d9-45d3-8389-2f1838aa64b8'}, 14: {'degree': 2, 'betweenness_centrality': 0.009746588693957114, 'feature1': 0.562444640362626, 'feature2': 94, 'feature3': 1, 'node_identifier': '583445bf-a5b1-488b-be2b-ce2792acb1e9'}, 15: {'degree': 1, 'betweenness_centrality': 0.0, 'feature1': 0.48048596950130473, 'feature2': 79, 'feature3': 1, 'node_identifier': '1cc47071-df78-4519-975b-d05c13b02edc'}, 16: {'degree': 2, 'betweenness_centrality': 0.009746588693957114, 'feature1': 0.43087159362106264, 'feature2': 11, 'feature3': 0, 'node_identifier': 'd42a474f-40e2-4ed6-a0d4-7be355b2f2df'}, 17: {'degree': 2, 'betweenness_centrality': 0.023391812865497075, 'feature1': 0.4862518026349286, 'feature2': 4, 'feature3': 1, 'node_identifier': 'e369fdd4-3e3d-4734-88b3-bbfdc2c3ddae'}, 18: {'degree': 1, 'betweenness_centrality': 0.0, 'feature1': 0.8249659730262445, 'feature2': 81, 'feature3': 0, 'node_identifier': 'c8951799-113b-4d23-8cca-43922fcc994e'}, 19: {'degree': 1, 'betweenness_centrality': 0.0, 'feature1': 0.015880737578735427, 'feature2': 41, 'feature3': 1, 'node_identifier': '91e379c0-62af-4312-8a15-6fd0616eb3fc'}})
